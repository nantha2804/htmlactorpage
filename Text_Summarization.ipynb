# %% [markdown]
# <a href="https://colab.research.google.com/github/nantha2804/htmlactorpage/blob/main/Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ARTICLE = """i have an old car ,the very pricious  I had an excellent experience!
              The quality exceeded my expectations, and the attention to detail was impressive.
              Everything was handled professionally, and the customer service was friendly, responsive, and truly went above and beyond.
              I’m extremely satisfied and would definitely choose this again. Highly recommended!
"""

# %%
# Load the summarization pipeline with the specified model
summarizer = pipeline("text-generation", model="facebook/bart-large-cnn")
# Out:
# Loading weights:   0%|          | 0/316 [00:00<?, ?it/s]
# [transformers] BartForCausalLM LOAD REPORT from: facebook/bart-large-cnn
# Key                                                       | Status     |  |
# ----------------------------------------------------------+------------+--+-
# model.encoder.layers.{0...11}.self_attn.out_proj.weight   | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc1.bias                    | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.k_proj.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.q_proj.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn_layer_norm.weight | UNEXPECTED |  |
# model.encoder.layers.{0...11}.final_layer_norm.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.k_proj.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn_layer_norm.bias   | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc1.weight                  | UNEXPECTED |  |
# ...

# %%
print(summarizer(ARTICLE, max_length=100, min_length=70, do_sample=False))
# Out:
# [{'generated_text': 'i have an old car ,the very pricious \nallyOneBarOneLastJAfterAfterAfterOneLastLastOneLastOne onlyLast onlyOneJOne only only onlyOneLast only last only only one only onlyLast " only only Only only only to only oneLast only only last one only one Only only one had only only still only onlyo only only this only onlycan only only both only only the only only had only had had had only Only one only this one only'}]

# %%
from transformers import pipeline
